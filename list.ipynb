# %%
# LIST
"""
list is collection of elements,
its mutable type of data structure,
its denoted by []
It can be of any type"""
# Out:
# '\nlist is collection of elements,\nits mutable type of data structure,\nits denoted by []\nIt can be of any type'

# %%
list1 = list(["abhi","age","salary"])

# %%
list1
# Out:
# ['abhi', 'age', 'salary']

# %%
list1[0]
# Out:
# 'abhi'

# %%
list1[1]
# Out:
# 'age'

# %%
for i in range(len(list1)):
    if list1[i]=="age":
        continue
    else:
        print(list1[i])
# Out:
# abhi
# salary

# %%
type(list1)
# Out:
# list

# %%
name = "abhishek"

# %%
name.upper()
# Out:
# 'ABHISHEK'

# %%
name.lower()
# Out:
# 'abhishek'

# %%
listp = [1,2,"abhi",55]

# %%
listp.insert(0,22)

# %%
listp
# Out:
# [22, 1, 2, 'abhi', 55]

# %%
listp.append(99)

# %%
listp.append(55,33,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 listp.append(55,33,3)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
list.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 list.pop()
#
# TypeError: unbound method list.pop() needs an argument

# %%
list
# Out:
# list

# %%
listp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 listp
#
# NameError: name 'listp' is not defined

# %%
list1 = list(["abhi","age","salary"])

# %%
list1
# Out:
# ['abhi', 'age', 'salary']

# %%
list1.insert(-1,'email')

# %%
list1
# Out:
# ['abhi', 'age', 'email', 'email', 'email', 'salary']

# %%
list1
# Out:
# ['abhi', 'age', 'email', 'email', 'email', 'salary']

# %%
list1.append("blood group")

# %%
list!
# Out:
#   Cell In[14], line 1
#     list!
#         ^
# SyntaxError: invalid syntax

# %%
list1
# Out:
# ['abhi', 'age', 'email', 'email', 'email', 'salary', 'blood group']

# %%
list1.pop(2)
# Out:
# 'email'

# %%
list1.pop(2)
# Out:
# 'email'

# %%
list1
# Out:
# ['abhi', 'age', 'email', 'salary', 'blood group']

# %%
list1.update(["roll","address"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 list1.update(["roll","address"])
#
# AttributeError: 'list' object has no attribute 'update'

# %%
list1.extend([1,23,4])

# %%
list1
# Out:
# ['abhi', 'age', 'email', 'salary', 'blood group', 1, 23, 4]

# %%
list1.remove('age')

# %%
list1
# Out:
# ['abhi', 'email', 'salary', 'blood group', 1, 23, 4]

# %%
list1.clear()

# %%
list1
# Out:
# []

# %%
del list1

# %%
list1 =[1,2,34,4]

# %%
list1
# Out:
# [1, 2, 34, 4]
