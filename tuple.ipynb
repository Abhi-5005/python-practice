# %%
# TUPLE

# %%
tup = (1,2,3,4,5,"abhi")

# %%
type(tup)
# Out:
# tuple

# %%
tup[0]
# Out:
# 1

# %%
tup[-1]
# Out:
# 'abhi'

# %%
list1 = list(tup)

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 'abhi']

# %%
list1[0]= 100

# %%
list1
# Out:
# [100, 2, 3, 4, 5, 'abhi']

# %%
tup
# Out:
# (1, 2, 3, 4, 5, 'abhi')

# %%
tup = tuple(list1)

# %%
tup
# Out:
# (100, 2, 3, 4, 5, 'abhi')

# %%
tup.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tup.count()
#
# TypeError: tuple.count() takes exactly one argument (0 given)

# %%
tup.count(100
         )
# Out:
# 1

# %%
tup.
