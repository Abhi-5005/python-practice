# %%
L1 = [20, 40, 50, 10, 6, 80, 20, 50, 10, 6, 80]
#{20: 2, 40: 1, 50: 2, 10: 2, 6: 2, 80: 2}

dis ={}

for i in L1:
    if i in dis:
       
        dis[i]+=1
    else:
        dis[i]=1
dis
# Out:
# {20: 2, 40: 1, 50: 2, 10: 2, 6: 2, 80: 2}

# %%
data = [(1, 'A'), (2, 'B'), (3, 'C')] 

dis={}

for i in data:
    dis[i[0]]= i[1]

# %%
dis
# Out:
# {1: 'A', 2: 'B', 3: 'C'}

# %%
string = 'level'
rev = ""
for i in range(-1,-len(string)-1,-1):
    rev = rev + string[i]
rev
if string == rev:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome

# %%
nums = [5, -3, 7, -1, 9]

for i in nums:
    if i>0:
        continue
    else:
        nums.remove(i)

# %%
nums
# Out:
# [5, 7, 9]

# %%
files = ['data.csv', 'report.json', 'script.py']

for i in files:
    if i.endswith(".csv"):
        print("csv type")
    elif i.endswith(".json"):
        print("json type")
    else:
        print("py type")
# Out:
# csv type
# json type
# py type

# %%
texts = ['python', 'ai', 'etl']
lis =[]
for i in texts:
    lis.append(len(i))

# %%
lis
# Out:
# [6, 2, 3]

# %%
errors = {'log1': 'ok', 'log2': 'error found', 'log3': 'ok'}

for i in errors:
    if errors[i]=='error found':
        print(i)
# Out:
# log2

# %%
 d = {'a': [1, 2], 'b': [3, 4]}
lis= []
for i in d:
    lis.append((i,d[i]))

# %%
lis
# Out:
# [('a', [1, 2]), ('b', [3, 4])]

# %%
log = 'error success error warning error'
dis = {}
for i in log:
    if i != " ":
        if i in dis:
            dis[i]+=1
        else:
            dis[i]=1


dis
# Out:
# {'e': 4,
#  'r': 10,
#  'o': 3,
#  's': 3,
#  'u': 1,
#  'c': 2,
#  'w': 1,
#  'a': 1,
#  'n': 2,
#  'i': 1,
#  'g': 1}

# %%
files = ['data.csv', 'report.txt', 'main.py', 'notes.txt']
f1 = []
for i in files:
    ext = i.split(".")[-1]
    if ext not in f1:
        f1.append(ext)
        
f1
# Out:
# ['csv', 'txt', 'py']

# %%
sizes = [50, 100, 150, 200] 
sum = 0
for i in sizes:
    sum = sum + i
sum
# Out:
# 500

# %%
cols = {'id', 'name', 'age'}

if 'salary' not in cols:
    cols.add("salary")
    
cols
# Out:
# {'age', 'id', 'name', 'salary'}

# %%
import time



ip = "0.0.0.0"

l1 = ip.split(".")
count = 0
if len(l1)==4:
    for i in l1:
        if i.isnumeric():
            if int(i)<256 and int(i)>=0:
                count+=1
            else:
                print("invalid")
                break
        else:
            print("invalid")
            break
    if count == 4:
        print("valid")
else:
    print("invalid")
# Out:
# valid

# %%
import time

start_time = time.time()  # start the timer

# --- Your IP validation code ---
ip = "0.0.0.0"

l1 = ip.split(".")
count = 0

if len(l1) == 4:
    for i in l1:
        if i.isnumeric():
            if 0 <= int(i) < 256:
                count += 1
            else:
                print("invalid")
                break
        else:
            print("invalid")
            break
    if count == 4:
        print("valid")
else:
    print("invalid")
# --- End of code ---

end_time = time.time()  # end the timer
print(f"Execution time: {end_time - start_time} seconds")
# Out:
# valid
# Execution time: 0.0006949901580810547 seconds

# %%
import time

start_time = time.time() 
ip = "192.168.1.1"

parts = ip.split('.')

if len(parts) == 4:  # IPv4 has 4 parts
    valid = True
    for part in parts:
        if not part.isdigit() or not 0 <= int(part) <= 255:
            valid = False
            break
    if valid:
        print("Valid 32-bit IPv4 address")
    else:
        print("Invalid IP address")
else:
    print("Invalid IP address")


end_time = time.time()  # end the timer
print(f"Execution time: {end_time - start_time} seconds")
# Out:
# Valid 32-bit IPv4 address
# Execution time: 0.0006697177886962891 seconds

# %%
data = [95, 65, 40, 30]

for i in data:
    if (i<=100 and i>=80):
        print("high")
    elif (i<=79 and i>=50):
        print("medium")
    else:
        print("low")
# Out:
# high
# medium
# low
# low

# %%
pairs = [('a', 1), ('b', 2), ('c', 3)]
dis={}

for i,j in pairs:
    dis[i]= j
    print(dis[i])
dis
# Out:
# 1
# 2
# 3
# {'a': 1, 'b': 2, 'c': 3}

# %%
datasets = {'sales': 1200, 'users': 800, 'logs': 1500}
for i in datasets:
    if datasets[i]>1000:
        print(i)
# Out:
# sales
# logs

# %%
names = ['amit', 'raj', 'neha']

l1 =[]
for i in names:
    rev = ""
    for j in range(-1,-len(i)-1,-1):
        rev = rev + i[j]
    l1.append(rev)

# %% [markdown]
# #

# %%
l1
# Out:
# ['tima', 'jar', 'ahen']

# %%
keys = ['id', 'name']
values = [1, 'Ravi']

dis={}

for i in values,pairs:
    print(len(values[i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[157], line 7
#       4 dis={}
#       6 for i in values,pairs:
# ----> 7     print(len(values[i]))
#
# TypeError: list indices must be integers or slices, not list
