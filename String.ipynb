# %%
# string

# %%
""" its high priority data structure
>> Its single character or multiple character arranged in perticular order
>> Its immutable type DS 
>> The indexing same as list /tuple
>> Its denoted by single quote , double quote , triple quote
"""
# Out:
# ' its high priority data structure\n>> Its single character or multiple character arranged in perticular order\n>> Its immutable type DS \n>> The indexing same as list /tuple\n>> Its denoted by single quote , double quote , triple quote\n'

# %%
name = "Abhishek"

# %% [markdown]
# name

# %%
name
# Out:
# 'Abhishek'

# %%
p = "python is programing lang and it's also use for ml and ai"

# %%
p = """ python is programing lang
it's also use for ml and ai"""

# %%
# Doc string

# %%
"""#/bin/python39      >> (she bang)
'''
the data injected from SFTP process and dump into MADB          >>  (doc string)
'''
import library      >> (globle variable)
global variables
def f1()           >> (function)
def f2()            
def main()         >> (main function)
if__ name__ =='__main__':          >> (triggering code)
    main()

    """
# Out:
# "#/bin/python39      >> (she bang)\n'''\nthe data injected from SFTP process and dump into MADB          >>  (doc string)\n'''\nimport library      >> (globle variable)\nglobal variables\ndef f1()           >> (function)\ndef f2()            \ndef main()         >> (main function)\nif__ name__ =='__main__':          >> (triggering code)\n    main()\n\n    "

# %%
p = "python"

# %%
p.upper()
# Out:
# 'PYTHON'

# %%
p.lower()
# Out:
# 'python'

# %%
p.capitalize()
# Out:
# 'Python'

# %%
p.title()
# Out:
# 'Python'

# %%
p = "python is programing lang"

# %%
p
# Out:
# 'python is programing lang'

# %%
p.title()
# Out:
# 'Python Is Programing Lang'

# %%
p = "pEfTE"

# %%
p.swapcase()
# Out:
# 'PeFte'

# %%
p = "python"

# %%
p.replace('p','j')
# Out:
# 'jython'

# %%
p = "pythonpppp"

# %%
p.replace('p','j',1)
# Out:
# 'jythonpppp'

# %%
p = """ python is programing lang
it's also use for ml and ai"""

# %%
p.splitlines()
# Out:
# [' python is programing lang', "it's also use for ml and ai"]

# %%
len(p)
# Out:
# 54

# %%
p.count("pythondfvfvf")
# Out:
# 0

# %%
region = "pune-wakad"

# %%
region.startswith('pune')
# Out:
# True

# %%
p ="copper_daily_2025.csv"

# %%
p.startswith("copper")
# Out:
# True

# %%
p.endswith('.csv')
# Out:
# True

# %%
t = 'test@gmail.com'

# %%
t(,@)
# Out:
#   Cell In[38], line 1
#     t(,@)
#       ^
# SyntaxError: invalid syntax

# %%
t.split('@')[0
]
# Out:
# 'test'

# %%
p
# Out:
# 'copper_daily_2025.csv'

# %%
p.split('_')[-1].split('.')[0].split('0')[-1].split('2')[-1]
# Out:
# '5'

# %%
strip()   >>> it's used to remove unnessarie white space from both the end
lstip()   >>> left end

rstrip()  >>> right end
# Out:
#   Cell In[54], line 1
#     strip()   >>> it's used to remove unnessarie white space from both the end
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
p = '   abhi  '

# %%
p.strip()
# Out:
# 'abhi'

# %%
p = '    abhi'

# %%
p.lstrip()
# Out:
# 'abhi'

# %%
p = 'abhi    '

# %%
p.rstrip()
# Out:
# 'abhi'

# %%
# how to insert dynamic content into string

# %%
 a = 10
b = 20 
c = a+b

# %%
c
# Out:
# 30

# %%
# format(var1,var2)

# %%
"addition of {} and {} is {}".format(b,a,c)
# Out:
# 'addition of 20 and 10 is 30'

# %%
f"addition of {a} and {b} is {c}."
# Out:
# 'addition of 10 and 20 is 30.'

# %%
p
# Out:
# 'abhi    '

# %%
p ="copper_daily_2025.csv"

# %%
p
# Out:
# 'copper_daily_2025.csv'

# %%
p
# Out:
# 'copper_daily_2025.csv'

# %%
p.find("zaily")
# Out:
# -1

# %%
str = "2025"
if str in p :
    p.index()
else:
    print("0")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 3
#       1 str = "2025"
#       2 if str in p :
# ----> 3     p.index()
#       4 else:
#       5     print("0")
#
# TypeError: index expected at least 1 argument, got 0

# %%
""" string is single char or multi char arrenged in perticular ordeer;
its immutable means we can not change or ulter the string,
Its scope is in " ",' ',""" """,''' '''
"""
# Out:
# ' string is single char or multi char arrenged in perticular ordeer;\nits immutable means we can not change or ulter the string,\nIts scope is in " ",\' \',,\'\'\' \'\'\'\n'

# %%
name = "Abhishek"

# %%
type(name)
# Out:
# str

# %%
len(name)
# Out:
# 8

# %%
for i in range(len(name)):
    print(name[i])
# Out:
# A
# b
# h
# i
# s
# h
# e
# k

# %%
name[3]
# Out:
# 'i'

# %%
name.count("i")
# Out:
# 1

# %%
name.index("i")
# Out:
# 3

# %%
#slicing of string

# %%
print(name[2:4])
# Out:
# hi

# %%
string = "In Python, a string is a sequence of characters, used to represent textual data.'\n' Strings are a fundamental data type in Python and are used extensively for handling text information."

# %%
string
# Out:
# "In Python, a string is a sequence of characters, used to represent textual data.'\n' Strings are a fundamental data type in Python and are used extensively for handling text information."

# %%
print(string)
# Out:
# In Python, a string is a sequence of characters, used to represent textual data.'
# ' Strings are a fundamental data type in Python and are used extensively for handling text information.

# %%
name
# Out:
# 'Abhishek'

# %%
name.upper()
# Out:
# 'ABHISHEK'

# %%
name.lower()
# Out:
# 'abhishek'

# %%
name.capitalize()
# Out:
# 'Abhishek'

# %%
string.capitalize()
# Out:
# "In python, a string is a sequence of characters, used to represent textual data.'\n' strings are a fundamental data type in python and are used extensively for handling text information."

# %%
string.title()
# Out:
# "In Python, A String Is A Sequence Of Characters, Used To Represent Textual Data.'\n' Strings Are A Fundamental Data Type In Python And Are Used Extensively For Handling Text Information."

# %%
string.upper()
# Out:
# "IN PYTHON, A STRING IS A SEQUENCE OF CHARACTERS, USED TO REPRESENT TEXTUAL DATA.'\n' STRINGS ARE A FUNDAMENTAL DATA TYPE IN PYTHON AND ARE USED EXTENSIVELY FOR HANDLING TEXT INFORMATION."

# %%
print(name)
# Out:
# Abhishek

# %%
name.replace('A','b')
# Out:
# 'bbhishek'

# %%
name  # because of immutable type of D S
# Out:
# 'Abhishek'

# %%
name = "   abhishek "

# %%
name.strip()
# Out:
# 'abhishek'

# %%
name.strip().upper()
# Out:
# 'ABHISHEK'

# %%
name.strip().upper().split('i')
# Out:
# ['ABHISHEK']

# %%
name
# Out:
# '   abhishek '

# %%
string1 = "hello"

# %%
string2 = "world"

# %%
print(string1+ " " +string2)
# Out:
# hello world

# %%
a = 10 
b = 20 
c= a+b

# %%
f"addition of number {a} and {b} is {c}"
# Out:
# 'addition of number 10 and 20 is 30'

# %%
print("Addition of number {} and {} is {}".format(a,b,b))
# Out:
# Addition of number 10 and 20 is 20

# %%
a = "my name is abhishek"

# %%
print(a)
# Out:
# my name is abhishek

# %%
name
# Out:
# '   abhishek '

# %%
name.casefold()
# Out:
# '   abhishek '

# %%
string
# Out:
# "In Python, a string is a sequence of characters, used to represent textual data.'\n' Strings are a fundamental data type in Python and are used extensively for handling text information."

# %%
string.split('.')[0]
# Out:
# 'In Python, a string is a sequence of characters, used to represent textual data'

# %%
string[0]
# Out:
# 'I'

# %%
name = "my name is abhishek"

# %%
if name.startswith("my") == True :
    print("yes here its")
# Out:
# yes here its

# %%
string
# Out:
# "In Python, a string is a sequence of characters, used to represent textual data.'\n' Strings are a fundamental data type in Python and are used extensively for handling text information."

# %%
string.center()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 string.center()
#
# TypeError: center expected at least 1 argument, got 0

# %%
a = "my name is abhi"

# %%
print(a)
# Out:
# my name is abhi

# %%
a = "chetan"

# %%
print(a)
# Out:
# chetan

# %%
a
# Out:
# 'chetan'

# %%
a = "Abhi"
a = "chetan"
print(a)
# Out:
# chetan

# %%
t = (1,2,3,4,5)

# %%
t = (1,2,3)

# %%
print(t)
# Out:
# (1, 2, 3)

# %%
name = "abhi"

# %%
name = "sjdoEFffd"

# %% [markdown]
# name

# %% [markdown]
# name

# %%
name
# Out:
# 'sjdoEFffd'

# %%
name.swapcase()
# Out:
# 'SJDOefFFD'

# %%
string
# Out:
# "In Python, a string is a sequence of characters, used to represent textual data.'\n' Strings are a fundamental data type in Python and are used extensively for handling text information."

# %%
string.find("string")
# Out:
# 13

# %%
name
# Out:
# 'sjdoEFffd'

# %%
name.isupper()
# Out:
# False

# %%
name.upper().isupper()
# Out:
# True

# %%
name ='abhi'

# %%
name.islower()
# Out:
# True

# %%
name.isalpha()
# Out:
# True

# %%
name.isnumeric()
# Out:
# False

# %%
name.isascii()
# Out:
# True

# %%
name.isalnum()
# Out:
# True

# %%
age = 12
